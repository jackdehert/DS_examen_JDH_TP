# %% [markdown]
# ## [96A - Football- Difficulty 900](https://codeforces.com/problemset/problem/96/A)
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### Put in dummy input

# %%
# 001001
# 1000000001
# 00100110111111101
# 11110111111111111

# %%
lineup = input()

if "0000000" in lineup or "1111111" in lineup:
    print("YES")
else:
    print("NO")
