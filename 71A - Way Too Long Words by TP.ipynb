# %% [markdown]
# ## [71A - Way Too Long Words - Difficulty 800](https://codeforces.com/problemset/problem/71/A)
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Put in dummy input

# %%
# 4
# word
# localization
# internationalization
# pneumonoultramicroscopicsilicovolcanoconiosis

# %%
n = int(input())

for i in range(n):
    word = input()
    if len(word) > 10:
        print(str(word[0])+str(len(word)-2)+word[-1])
    else:
        print(word)
