# %% [markdown]
# ## [579A - Raising Bacteria - Difficulty 1000](https://codeforces.com/problemset/problem/579/A)
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Put in dummy input

# %%
# 5
# 8
# 536870911

# %%
x = int(input())
count = 0

while x > 0:
    if x % 2 == 1:
        count += 1
    x //= 2
print(count)
