# %% [markdown]
# ## [208A - Dubstep - Difficulty 900](https://codeforces.com/problemset/problem/208/A)
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Put in dummy input

# %%
# WUBWUBABCWUB
# WUBWEWUBAREWUBWUBTHEWUBCHAMPIONSWUBMYWUBFRIENDWUB

# %%
remixed_song= input()

original_song = " ".join(filter(None, remixed_song.split("WUB"))) #filter(None, iterable) removes empty strings in the iterable
print(original_song)
