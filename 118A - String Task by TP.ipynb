# %% [markdown]
# ## [118A - String Task - Difficulty 1000 ](https://codeforces.com/problemset/problem/118/A)
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Put in dummy input

# %%
# tour
# Codeforces
# aBAcAba
# obn
# wpwl

# %%
my_string = input()
my_string = my_string.lower()
vowels = ["a", "o", "y", "e", "u", "i"]

for vowel in vowels:
    if vowel in my_string:
        mijn_string = my_string.replace(vowel,"")
final_string = ""
for character in my_string:
    final_string += "." + character
print(final_string)
