# %% [markdown]
# ## [236A - Boy or Girl - Difficulty 800](https://codeforces.com/problemset/problem/236/A)
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Put in dummy input

# %%
# wjmzbmr
# xiaodao
# sevenkplus

# %%
name = input()
distinct_name = ""

for letter in name:
    if letter not in distinct_name:
        distinct_name += letter
if len(distinct_name) % 2 == 0:
    print("CHAT WITH HER!")
else:
    print("IGNORE HIM!")
